# %% [markdown]
# #collection data types

# %% [markdown]
# List, Dictionaries & Tuples

# %% [markdown]
# ##Lists

# %%
#assign a list to a variable
my_list = [1,2,3]

# %%
my_list
# Out:
# [1, 2, 3]

# %% [markdown]
# ##Indexing and slicing

# %%
my_list = ['one', 'two', 'three', 4, 5]

# %%
my_list[1:]
# Out:
# ['two', 'three', 4, 5]

# %%
my_list[0]
# Out:
# 'one'

# %%
my_list[:3]
# Out:
# ['one', 'two', 'three']

# %%
#we can also use + to concatenate lists, just like we did for strings
my_list + ['new item']
# Out:
# ['one', 'two', 'three', 4, 5, 'new item']

# %%
#but it doesn't change the actual string
my_list
# Out:
# ['one', 'two', 'three', 4, 5]

# %%
#we have to concatenate and assign it to the original variable
my_list = my_list + ['add new item for good']

# %%
my_list
# Out:
# ['one', 'two', 'three', 4, 5, 'add new item for good']

# %%
my_list.append('Something')

# %%
my_list
# Out:
# ['one', 'two', 'three', 4, 5, 'add new item for good', 'Something']

# %%
#double the contents of the list 
my_list * 2
# Out:
# ['one',
#  'two',
#  'three',
#  4,
#  5,
#  'add new item for good',
#  'Something',
#  'one',
#  'two',
#  'three',
#  4,
#  5,
#  'add new item for good',
#  'Something']

# %%
#but changes aren't permanent
my_list
# Out:
# ['one', 'two', 'three', 4, 5, 'add new item for good', 'Something']

# %%
#create new list
l = [1, 2, 3]

# %%
#append
l.append('append me')

# %%
l.pop(0)
# Out:
# 1

# %%
l
# Out:
# [2, 3, 'append me']

# %%
mlist = ['string']

# %%
len(mlist)
# Out:
# 1

# %%
#use pop to "pop off" an item from the list. by default pop takes off the last index,
#but youcan also specify which index to pop off
l.pop
# Out:
# <function list.pop>

# %% [markdown]
# #The sort and revers methods

# %%
new_list = ['a', 'e', 'x', 'b', 'c']
new_list
# Out:
# ['a', 'e', 'x', 'b', 'c']

# %%
#use reverse to revers the order(this is pernmanent!)
new_list.reverse()
new_list
# Out:
# ['c', 'b', 'x', 'e', 'a']

# %%
#use sort to sort the list(in this case alphabetical order, but for numbers it will go ascending) 
new_list.sort()
new_list
# Out:
# ['a', 'b', 'c', 'e', 'x']

# %%
#to combine int and str you have to conver numbers to strings
nlist = ['a', 'x', 't', str(12), str(55)]
nlist.sort()
nlist
# Out:
# ['12', '55', 'a', 't', 'x']

# %% [markdown]
# #Dictionaries

# %%
#make a dictionarry with {} and : to signify a key and a value
my_dict = {'key1':123,'key2':[12,23,33], 'key3':['item0','item1','item2']}

# %%
#lets call items from the dictionary
my_dict['key3']
# Out:
# ['item0', 'item1', 'item2']

# %%
#call an index on that value
my_dict['key3'][0]
# Out:
# 'item0'

# %%
#you can even call methods on that value
my_dict['key3'][0].upper()
# Out:
# 'ITEM0'

# %%
my_dict['key1']
# Out:
# 123

# %%
#subtract 123 from the value
my_dict['key1'] = my_dict['key1'] - 123

# %%
#we can also create keys by assignment. FOr instance if we started off woth an empty dictionary we can
#creat a new dictionary
d = {}

# %%
#create a new key through assignment
d['animal'] = 'Dog'

# %%
#you can do this with any object
d['answer'] = 42

# %%
d
# Out:
# {'animal': 'Dog', 'answer': 42}

# %% [markdown]
# ##Dictionary Methods

# %%
#creat a typical dictionary
d = {'key':1,'key2':2,'key3':3}

# %%
#Method to return  a list of all keys
d.keys()
# Out:
# dict_keys(['key', 'key2', 'key3'])

# %%
#method to grab all values
d.values()
# Out:
# dict_values([1, 2, 3])

# %%
#method to return tuples of all items (we'll learn about tuples soon)
d.items()
# Out:
# dict_items([('key', 1), ('key2', 2), ('key3', 3)])

# %% [markdown]
# #Tuple

# %% [markdown]
# In python tuples are very similar to lists, however,unlike lists they are immutable meaning they can not be changed You would use tuples
# to present htings that should not be changed, such as days of the week, or dates of the calendar.

# %%
#you can create a tuple with muixed types
t = (1,2,3)

# %%
#check length just like a list
len(t)
# Out:
# 3

# %%
#can also mix object types
t = ('one',2)

#show
t
# Out:
# ('one', 2)

# %%
#use index just like we did in lists
t[0]
# Out:
# 'one'

# %%
#slicing just like a list
t[-1]
# Out:
# 2

# %%
##Tuple methods

# %%
t.index('one')
# Out:
# 0

# %%
#use .count to count the nu,ber of times a value appears
t.count('one')
# Out:
# 1

# %%
t.count(2)
# Out:
# 1
