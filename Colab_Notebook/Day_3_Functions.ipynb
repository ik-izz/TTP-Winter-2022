# %% [markdown]
# #Functions

# %% [markdown]
# #So what is a function
# Formally, a function is a useful device that groups together a set of statements so they can be run more than once. They can also let us specify parameters that can serve as inputs to the functions.
#
# On a more fundamental level, functions allow us to not have to repeatedly write the same code again and again. If you remember back to the lessons on strings and lists, remember that we used a function len() to get the length of a string. Since checking the length of a sequence is a common task you would want to write a function that can do this repeatedly at command.
#
# Functions will be one of most basic levels of reusing code in Python, and it will also allow us to start thinking of program design (we will dive much deeper into the ideas of design when we learn about Object Oriented Programming).

# %% [markdown]
# ##def Statemennts
# Let's see how to build out a function's syntax in Python. It has the following form:

# %%
def name_of_function(arg1,arg2):
    '''
    This is where the function's Document String (doc-string) goes
    '''
    # Do stuff here
    #return desired result

# %%
def say_hello():
  print('hello')

# %%
say_hello()
# Out:
# hello

# %%
def greetings(name):
  '''
  Author
  Input: name
  Output: hello name 
  '''
  print(f'Hello there {name}')

greetings('Israel')
# Out:
# Hello there Israel

# %%
def add_num(x, y):
  return x + y

# %%
add_num(34, 6)
# Out:
# 40

# %%
#Write a function that checks if a number is prime.!

# 1. What do we want?
# we want a function that checks if a number is prime

# 2. What do we need?
#   I need to first define what a prime number is. 
#   then, design some type of methodology to pass a number and check if a number is prime or not.

# 3. What do we have
#     We have Python, definition of prime numbers: a prime number is only divisible by itself and by 1

# %%
def isPrime(n):
  for i in range(2, n):
    if n % i == 0:
      print(f'The number {n} is not prime')
      break
  else:
      print(f'The number {n} is prime')

# %%
isPrime(9)
# Out:
# The number 9 is not prime

# %%
#store data into a variable with "return"

def greetings(name = 'Mark'):
  return 'Hello ' + name

greetings('Israel')
# Out:
# 'Hello Israel'

# %%
def even_number(l):
  '''
  It's a function to print even numbers
  Input: A list with numbers
  output: A list with even numbers
 '''
  enum = []
  for n in l:
    if n % 2 == 0:
      enum.append(n)
  return(enum)

# %%
#returns function documentation
help(even_number)
# Out:
# Help on function even_number in module __main__:
#
# even_number(l)
#     It's a function to print even numbers
#     Input: A list with numbers
#     output: A list with even numbers

# %%
even_number([123, 23456, 8765, 8765, 987, 666, 453, 21345, 6789, 98765, 22223, 34556, 78])
# Out:
# [23456, 666, 34556, 78]

# %%
x = input('Enter a number')
# Out:
# Enter a number24

# %%
def temp(pick,num):
    pick=int(pick)
    num=int(num)
    if pick==1:
        celcius=(num-32)*5/9
        kelvin=(num-32)*5/9+273.15
        print("celcius="+str(celcius))
        print("kelvin="+str(kelvin))
    if pick==2:
        fahrenheit=(num*9/5)+32
        kelvin=num+273.15
        print("fahrenheit="+str(fahrenheit))
        print("kelvin="+str(kelvin))
    if pick==3:
        fahrenheit=(num-273.15)*9/5+32
        celcius=num-273.15
        print("fahrenheit="+str(fahrenheit))
        print("celcius="+str(celcius))



print("Pick a temperature 1.Fahrenheit 2.celsius 3.kelvin")
pick=input("input: ")
num=input("Enter the degrees: ")
temp(pick,num)
# Out:
# Pick a temperature 1.Fahrenheit 2.celsius 3.kelvin
# input: 2
# Enter a the degrees: 25
# fahrenheit=77.0
# kelvin=298.15
