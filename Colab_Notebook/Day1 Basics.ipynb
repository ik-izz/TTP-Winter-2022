# %% [markdown]
# #Hello Pyhton

# %%
print('Hello there')
# Out:
# Hello there

# %%
import this

# %% [markdown]
# #String Basics

# %%
'This is a string'
a = 'This is a string'
len('This is a string')
len(a)
# Out:
# 16

# %%
'This is string #2'
b = 'This is a string#2'
len('This is a string#2')
len(b)
# Out:
# 18

# %%
'this is string #3'
c = 'this is string #3'
len('this is string #3')
len(c)
# Out:
# 17

# %%
'this is string #4'
d = 'this is string #4'
len('this is string #4')
len(d)
# Out:
# 17

# %%
'this is string #5'
e = 'this is string #5'
len('this is string #5')
len(e)
# Out:
# 17

# %% [markdown]
# ##String Index

# %%
# Print the object
print(a)
# Out:
# This is a string

# %%
#show first element
a[0]
# Out:
# 'T'

# %%
#show second element
a[1]
# Out:
# 'h'

# %%
#show third element
a[2]
# Out:
# 'i'

# %%
#show fourth element
a[3]
# Out:
# 's'

# %% [markdown]
# ##Concatenation of the string's

# %%
greeting = 'Hello'
name = 'Mark'
print(greeting + name)
print(greeting + " " + name)
print(greeting + ' ' + str(7))
# Out:
# HelloMark
# Hello Mark
# Hello 7

# %% [markdown]
# #Input Fucntion

# %%
greeting = 'Hello '
name = input('What is you name?')
print(greeting + name)
# Out:
# What is you name?Israel
# Hello Israel

# %%
'''
task:
  1. ask the user for name, age, and city.
  2. print out a greeting for it.
'''
# Out:
# '\ntask:\n  1. ask the user for name, age, and city.\n  2. print out a greeting for it.\n'

# %%
name = input('Enter your name')
age = input('Enter your age')
city = input('Enter your city')

print(f'Hello {name} you are {age} years old and you live in {city}')
# Out:
# Enter your nameISrael
# Enter your age21
# Enter your cityWhite Plains
# Hello ISrael you are 21 years old and you live in White Plains

# %%
print('Hello {} you are {} years old and you live in {}'.format(name, age, city))
# Out:
# Hello ISrael you are 21 years old and you live in White Plains

# %%
print('The colors are {} {} {}'.format('Red', 'Green', 'blue'))
# Out:
# The colors are Red Green blue

# %%
print('The colors are {0} {1} {2}'.format('Red', 'Green', 'blue'))
# Out:
# The colors are Red Green blue

# %%
print('The colors are {0} {0} {0}'.format('Red', 'Green', 'blue'))
# Out:
# The colors are Red Red Red

# %%
print('The colors are {2} {1} {0}'.format('Red', 'Green', 'blue'))
# Out:
# The colors are blue Green Red

# %%
print('The colors are {2} {2} {2}'.format('Red', 'Green', 'blue'))
# Out:
# The colors are blue blue blue

# %%
print('The colors are {r} {g} {b}'.format(r = 'Red',g = 'Green',b = 'blue'))
# Out:
# The colors are Red Green blue

# %% [markdown]
# #Numbers

# %%
a = 14
#initialized a to 14
print(a)
#prints a
# Out:
# 14

# %%
b = 4
#initialized b to 4
print(b)
#print out b
# Out:
# 4

# %%
print(a +b)
#add the value stored in a and the value in b and prints the results
# Out:
# 18

# %%
print(a - b)
#subtracts the value in a with the value of b
# Out:
# 10

# %%
print(a * b)
# Out:
# 56

# %%
print(a /b)
# Out:
# 3.5

# %%
print(a // b)
# Out:
# 3
